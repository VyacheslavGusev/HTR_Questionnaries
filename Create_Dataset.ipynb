# %% [markdown]
# ## Пробный датасет под CRNN

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import shutil
from PIL import Image
import pandas as pd
import numpy as np

# %%
gt = pd.DataFrame(columns=['fn', 'value'])

with open('/content/drive/MyDrive/Datasets/fields/fields_m.txt', 'r') as f:
  for index, row in enumerate(f):
    if row[0] == '#':
      continue
    row = row.split()
    gt.loc[gt.shape[0]] = (row[0], row[-1].replace('|', ' '))
gt.head(5)
# Out:
#         fn              value
# 0  01_0002    Фамилия Кунарев
# 1  01_0004  Фамилия Кириллина
# 2  01_0005     Фамилия Сурова
# 3  01_0006   Фамилия Кузнецов
# 4  01_0007  Фамилия: Кузнецов

# %%
# Пути к исходной и целевой директориям
source_dir = "/content/drive/MyDrive/Datasets/fields"
target_dir = "/content/drive/MyDrive/Datasets/fields_m"

# Убедимся, что целевые папки 01, 02, 03 существуют
for folder in ["01", "02", "03"]:
    os.makedirs(os.path.join(target_dir, folder), exist_ok=True)

# %%
# Получаем список имен файлов без расширения из колонки fn
file_names = set(gt['fn'].tolist())

# Проходим по каждой папке в исходной директории
for folder in ["01", "02", "03"]:
    folder_path = os.path.join(source_dir, folder)

    # Проверяем наличие папки
    if not os.path.exists(folder_path):
        print(f"Папка {folder_path} не существует.")
        continue

    # Перебираем все файлы в текущей папке
    for file in os.listdir(folder_path):
        # Получаем имя файла без расширения
        file_name_no_ext = os.path.splitext(file)[0]

        # Если имя файла (без расширения) есть в списке имен из DataFrame
        if file_name_no_ext in file_names:
            source_path = os.path.join(folder_path, file)
            target_path = os.path.join(target_dir, folder, file)

            # Копируем файл в целевую директорию
            shutil.copy2(source_path, target_path)
            print(f"Файл {file} скопирован в {target_path}")
# Out:
# Файл 01_0432.png скопирован в /content/drive/MyDrive/Datasets/fields_m/01/01_0432.png
# Файл 01_0435.png скопирован в /content/drive/MyDrive/Datasets/fields_m/01/01_0435.png
# Файл 01_0436.png скопирован в /content/drive/MyDrive/Datasets/fields_m/01/01_0436.png
# Файл 01_0433.png скопирован в /content/drive/MyDrive/Datasets/fields_m/01/01_0433.png
# Файл 01_0434.png скопирован в /content/drive/MyDrive/Datasets/fields_m/01/01_0434.png
# Файл 01_0441.png скопирован в /content/drive/MyDrive/Datasets/fields_m/01/01_0441.png
# Файл 01_0440.png скопирован в /content/drive/MyDrive/Datasets/fields_m/01/01_0440.png
# Файл 01_0439.png скопирован в /content/drive/MyDrive/Datasets/fields_m/01/01_0439.png
# Файл 01_0444.png скопирован в /content/drive/MyDrive/Datasets/fields_m/01/01_0444.png
# Файл 01_0445.png скопирован в /content/drive/MyDrive/Datasets/fields_m/01/01_0445.png
# Файл 01_0449.png скопирован в /content/drive/MyDrive/Datasets/fields_m/01/01_0449.png
# Файл 01_0447.png скопирован в /content/drive/MyDrive/Datasets/fields_m/01/01_0447.png
# Файл 01_0446.png скопирован в /content/drive/MyDrive/Datasets/fields_m/01/01_0446.png
# Файл 01_0450.png скопирован в /content/drive/MyDrive/Datasets/fields_m/01/01_0450.png
# Файл 01_0451.png скопирован в /content/drive/MyDrive/Datasets/fields_m/01/01_0451.png
# Файл 01_0454.png скопирован в /content/drive/MyDrive/Datasets/fields_m/01/01_0454.png
# Файл 01_0455.png скопирован в /content/drive/MyDrive/Datasets/fields_m/01/01_0455.png
# Файл 01_0453.png скопирован в /content/drive/MyDrive/Datasets/fields_m/01/01_0453.png
# Файл 01_0452.png скопирован в /content/drive/MyDrive/Datasets/fields_m/01/01_0452.png
# Файл 01_0458.png скопирован в /content/drive/MyDrive/Datasets/fields_m/01/01_0458.png
# Файл 01_0459.png скопирован в /content/drive/MyDrive/Datasets/fields_m/01/01_0459.png
# Файл 01_0456.png скопирован в /content/drive/MyDrive/Datasets/fields_m/01/01_0456.png
# Файл 01_0462.png скопирован в /content/drive/MyDrive/Datasets/fields_m/01/01_0462.png
# Файл 01_0460.png скопирован в /content/drive/MyDrive/Datasets/fields_m/01/01_0460.png
# Файл 01_0463.png скопирован в /content/drive/MyDrive/Datasets/fields_m/01/01_0463.png
# Файл 01_0466.png скопирован в /content/drive/MyDrive/Datasets/fields_m/01/01_0466.png
# Файл 01_0468.png скопирован в /content/drive/MyDrive/Datasets/fields_m/01/01_0468.png
# Файл 01_0465.png скопирован в /content/drive/MyDrive/Datasets/fields_m/01/01_0465.png
# Файл 01_0467.png скопирован в /content/drive/MyDrive/Datasets/fields_m/01/01_0467.png
# Файл 01_0471.png скопирован в /content/drive/MyDrive/Datasets/fields_m/01/01_0471.png
# Файл 01_0472.png скопирован в /content/drive/MyDrive/Datasets/fields_m/01/01_0472.png
# Файл 01_0473.png скопирован в /content/drive/MyDrive/Datasets/fields_m/01/01_0473.png
# Файл 01_0474.png скопирован в /content/drive/MyDrive/Datasets/fields_m/01/01_0474.png
# Файл 01_0475.png скопирован в /content/drive/MyDrive/Datasets/fields_m/01/01_0475.png
# Файл 01_0477.png скопирован в /content/drive/MyDrive/Datasets/fields_m/01/01_0477.png
# Файл 01_0481.png скопирован в /content/drive/MyDrive/Datasets/fields_m/01/01_0481.png
# Файл 01_0479.png скопирован в /content/drive/MyDrive/Datasets/fields_m/01/01_0479.png
# Файл 01_0482.png скопирован в /content/drive/MyDrive/Datasets/fields_m/01/01_0482.png
# Файл 01_0480.png скопирован в /content/drive/MyDrive/Datasets/fields_m/01/01_0480.png
# Файл 01_0485.png скопирован в /content/drive/MyDrive/Datasets/fields_m/01/01_
png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0438.png
# Файл 03_0440.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0440.png
# Файл 03_0439.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0439.png
# Файл 03_0442.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0442.png
# Файл 03_0443.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0443.png
# Файл 03_0444.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0444.png
# Файл 03_0446.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0446.png
# Файл 03_0445.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0445.png
# Файл 03_0447.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0447.png
# Файл 03_0448.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0448.png
# Файл 03_0450.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0450.png
# Файл 03_0449.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0449.png
# Файл 03_0451.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0451.png
# Файл 03_0452.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0452.png
# Файл 03_0457.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0457.png
# Файл 03_0454.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0454.png
# Файл 03_0458.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0458.png
# Файл 03_0456.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0456.png
# Файл 03_0455.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0455.png
# Файл 03_0461.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0461.png
# Файл 03_0462.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0462.png
# Файл 03_0460.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0460.png
# Файл 03_0459.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0459.png
# Файл 03_0465.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0465.png
# Файл 03_0463.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0463.png
# Файл 03_0464.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0464.png
# Файл 03_0467.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0467.png
# Файл 03_0469.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0469.png
# Файл 03_0472.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0472.png
# Файл 03_0471.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0471.png
# Файл 03_0470.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0470.png
# Файл 03_0473.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0473.png
# Файл 03_0475.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0475.png
# Файл 03_0474.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0474.png
# Файл 03_0476.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0476.png
# Файл 03_0477.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0477.png
# Файл 03_0478.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0478.png
# Файл 03_0481.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0481.png
# Файл 03_0479.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0479.png
# Файл 03_0482.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0482.png
# Файл 03_0483.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0483.png
# Файл 03_0484.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0484.png
# Файл 03_0485.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0485.png
# Файл 03_0487.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0487.png
# Файл 03_0490.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0490.png
# Файл 03_0491.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0491.png
# Файл 03_0489.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0489.png
# Файл 03_0492.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0492.png
# Файл 03_0495.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0495.png
# Файл 03_0494.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0494.png
# Файл 03_0493.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0493.png
# Файл 03_0498.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0498.png
# Файл 03_0496.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0496.png
# Файл 03_0502.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0502.png
# Файл 03_0500.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0500.png
# Файл 03_0501.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0501.png
# Файл 03_0506.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0506.png
# Файл 03_0505.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0505.png
# Файл 03_0508.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0508.png
# Файл 03_0509.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0509.png
# Файл 03_0511.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0511.png
# Файл 03_0513.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0513.png
# Файл 03_0510.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0510.png
# Файл 03_0512.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0512.png
# Файл 03_0515.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0515.png
# Файл 03_0514.png скопирован в /content/drive/MyDrive/Datasets/fields_m/03/03_0514.png

# %% [markdown]
# ## Датасет под Transformer

# %%
# Путь к папке с изображениями и текстовому файлу
image_folder = '/content/drive/MyDrive/Datasets/fields_transf_train'
text_file_path = '/content/drive/MyDrive/Datasets/fields/fields.txt'

# Чтение списка файлов в папке (оставляем только имена без расширения)
image_files = {os.path.splitext(filename)[0] for filename in os.listdir(image_folder) if filename.endswith('.png')}

gt = pd.DataFrame(columns=['fn', 'value'])

with open(text_file_path, 'r') as f:
  for index, row in enumerate(f):
    if row[0] == '#':
      continue
    row = row.split()
    gt.loc[gt.shape[0]] = (row[0] +'.png', row[-1].replace('\\', ' '))

# Фильтрация строк, где имя файла есть в списке image_files
gt_filtered = gt[gt['fn'].str.replace('.png', '').isin(image_files)]

# Вывод первых 5 строк отфильтрованного датафрейма
gt_filtered.head(10)
# Out:
#             fn                value
# 0  01_0002.png      Фамилия Кунарев
# 1  01_0004.png    Фамилия Кириллина
# 2  01_0005.png       Фамилия Сурова
# 3  01_0006.png     Фамилия Кузнецов
# 4  01_0007.png    Фамилия: Кузнецов
# 5  01_0008.png  Фамилия: Атаджанова
# 6  01_0009.png      Фамилия Потапов
# 7  01_0010.png     Фамилия: Сафонов
# 8  01_0011.png   Фамилия: Сичинская
# 9  01_0013.png      Фамилия: Алашев

# %%
# Путь к папке с файлами
image_folder = '/content/drive/MyDrive/Datasets/fields_transf_train'

# Получаем список всех файлов в папке
files_in_folder = set(os.listdir(image_folder))

# Получаем список файлов из колонки fn датафрейма
files_in_df = set(gt_filtered['fn'].tolist())

# Находим файлы, которые есть в папке, но отсутствуют в датафрейме
files_not_in_df = files_in_folder - files_in_df

# Выводим результат
print("Файлы, которых нет в датафрейме:")
for file in files_not_in_df:
    print(file)
# Out:
# Файлы, которых нет в датафрейме:

# %%
gt_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2560 entries, 0 to 3332
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   fn      2560 non-null   object
#  1   value   2560 non-null   object
# dtypes: object(2)
# memory usage: 60.0+ KB

# %%
output_file = 'fields_transf_train.tsv'
gt_filtered.to_csv(output_file, sep='\t', index=False, header=False)

print(f"Файл {output_file} успешно сохранен.")
# Out:
# Файл fields_transf_train.tsv успешно сохранен.

# %%
# Путь к папке с изображениями и текстовому файлу
image_folder = '/content/drive/MyDrive/Datasets/fields_transf_test'
text_file_path = '/content/drive/MyDrive/Datasets/fields/fields.txt'

# Чтение списка файлов в папке (оставляем только имена без расширения)
image_files = {os.path.splitext(filename)[0] for filename in os.listdir(image_folder) if filename.endswith('.png')}

gt = pd.DataFrame(columns=['fn', 'value'])

with open(text_file_path, 'r') as f:
  for index, row in enumerate(f):
    if row[0] == '#':
      continue
    row = row.split()
    gt.loc[gt.shape[0]] = (row[0] +'.png', row[-1].replace('\\', ' '))

# Фильтрация строк, где имя файла есть в списке image_files
gt_filtered = gt[gt['fn'].str.replace('.png', '').isin(image_files)]

# Вывод первых 5 строк отфильтрованного датафрейма
gt_filtered.head(10)
# Out:
#               fn              value
# 600  01_0857.png   Фамилия Метелкин
# 601  01_0858.png   Фамилия Курдюмов
# 602  01_0874.png     Фамилия Байден
# 603  01_0876.png   Фамилия Симонова
# 604  01_0878.png  Фамилия Ястребова
# 605  01_0880.png    Фамилия Сталоне
# 606  01_0881.png   Фамилия Лундгрен
# 607  01_0884.png      Фамилия Трамп
# 608  01_0885.png       Фамилия Грей
# 609  01_0888.png    Фамилия Володин

# %%
gt_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 770 entries, 600 to 3189
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   fn      770 non-null    object
#  1   value   770 non-null    object
# dtypes: object(2)
# memory usage: 18.0+ KB

# %%
output_file = 'fields_transf_test.tsv'
gt_filtered.to_csv(output_file, sep='\t', index=False, header=False)

print(f"Файл {output_file} успешно сохранен.")
# Out:
# Файл fields_transf_test.tsv успешно сохранен.
