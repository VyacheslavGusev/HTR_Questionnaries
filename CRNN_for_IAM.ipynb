# %%
import os
import math
import string

import cv2
import numpy as np
import pandas as pd
from tqdm import tqdm
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

import tensorflow as tf
import tensorflow.keras.backend as K
from tensorflow.keras.backend import get_value, ctc_decode
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Nadam

from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Prepare dataset

# %%
# !mkdir lines
# https://fki.tic.heia-fr.ch/DBs/iamDB/data/lines.tgz
# !tar -xf path/to/lines.tgz -C ./lines
# https://fki.tic.heia-fr.ch/DBs/iamDB/data/ascii.tgz
# !tar -xf path/to/ascii.tar -C ./

# %%
# Load labels

gt = pd.DataFrame(columns=['fn', 'value'])

with open('/content/drive/MyDrive/lines.txt', 'r') as f:
  for index, row in enumerate(f):
    if row[0] == '#':
      continue
    row = row.split()
    gt.loc[gt.shape[0]] = (row[0], row[-1].replace('|', ' '))
gt.head(5)
# Out:
#             fn                                  value
# 0  a01-000u-00      A MOVE to stop Mr. Gaitskell from
# 1  a01-000u-01  nominating any more Labour life Peers
# 2  a01-000u-02   is to be made at a meeting of Labour
# 3  a01-000u-03     Ps tomorrow . Mr. Michael Foot has
# 4  a01-000u-04   put down a resolution on the subject

# %%
# Data preprocessing

def preprocess(img):
  for func in [resize_n_rotate, add_adaptiveThreshold]:
    img = func(img)
  return img


def resize_n_rotate(img, shape_to=(64, 800)):
  if img.shape[0] > shape_to[0] or img.shape[1] > shape_to[1]:
    shrink_multiplayer = min(math.floor(shape_to[0] / img.shape[0] * 100) / 100,
                             math.floor(shape_to[1] / img.shape[1] * 100) / 100)
    img = cv2.resize(img, None,
                     fx=shrink_multiplayer,
                     fy=shrink_multiplayer,
                     interpolation=cv2.INTER_AREA)

  img = cv2.copyMakeBorder(img, math.ceil(shape_to[0]/2) - math.ceil(img.shape[0]/2),
                           math.floor(shape_to[0]/2) - math.floor(img.shape[0]/2),
                           math.ceil(shape_to[1]/2) - math.ceil(img.shape[1]/2),
                           math.floor(shape_to[1]/2) - math.floor(img.shape[1]/2),
                           cv2.BORDER_CONSTANT, value=255)
  return cv2.rotate(img, cv2.ROTATE_90_CLOCKWISE)


def add_adaptiveThreshold(img):
  return cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY_INV, 21, 10).astype('bool')


# Label encoding

def encode_text(texts):
  def _label_to_num(label, alphabet):
    label_num = []
    for ch in label:
      label_num.append(alphabet.find(ch))
    return np.array(label_num)

  alphabet = ''.join(sorted(pd.Series(texts).apply(list).apply(pd.Series).stack().unique()))

  nums = np.ones([len(texts), max([len(text) for text in texts])], dtype='int64') * len(alphabet)
  for i, text in enumerate(texts):
    nums[i][:len(text)] = _label_to_num(text, alphabet)

  return nums, alphabet

# %%
# Load and preprocess data

train_X, train_y = [], []

for sub_folder1 in tqdm(os.listdir('/content/drive/MyDrive/Datasets/lines')):
  for sub_folder2 in os.listdir(f'/content/drive/MyDrive/Datasets/lines/{sub_folder1}'):
    for sub_folder3 in os.listdir(f'/content/drive/MyDrive/Datasets/lines/{sub_folder1}/{sub_folder2}'):

      label = gt[gt.fn == sub_folder3[:sub_folder3.rfind('.')]].value.tolist()[0]
      if not any(list(map(lambda e: e not in string.ascii_letters + ',.\' ', label))):
        train_X.append(preprocess(cv2.imread(f'/content/drive/MyDrive/Datasets/lines/{sub_folder1}/{sub_folder2}/{sub_folder3}', 0)))
        train_y.append(gt[gt.fn == sub_folder3[:sub_folder3.rfind('.')]].value.tolist()[0])

train_X = np.array(train_X)
train_y, alphabet = encode_text(train_y)
alphabet
# Out:
# 100%|██████████| 51/51 [43:37<00:00, 51.32s/it]
# " ',.ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz"

# %%
train_X, val_X, train_y, val_y  = train_test_split(train_X, train_y, test_size=0.2, random_state=42)
train_X, test_X, train_y, test_y  = train_test_split(train_X, train_y, test_size=0.25, random_state=42)

# %%
fig, axes = plt.subplots(figsize=(20, 15), ncols=2, nrows=10)

# Preprocess example

for i in range(10):
  for j in range(2):
    axes[i, j % 2].imshow(cv2.rotate(
        (train_X[i * 2 + j % 2]).astype(np.uint8),cv2.ROTATE_90_COUNTERCLOCKWISE),
        cmap='gray')

# %% [markdown]
# # Model

# %%
class CERMetric(tf.keras.metrics.Metric):
    """
    A custom Keras metric to compute the Character Error Rate
    """
    def __init__(self, name='CER_metric', **kwargs):
        super(CERMetric, self).__init__(name=name, **kwargs)
        self.cer_accumulator = self.add_weight(name="total_cer", initializer="zeros")
        self.counter = self.add_weight(name="cer_count", initializer="zeros")

    def update_state(self, y_true, y_pred, sample_weight=None):
        input_shape = K.shape(y_pred)
        input_length = tf.ones(shape=input_shape[0]) * K.cast(input_shape[1], 'float32')

        decode, log = K.ctc_decode(y_pred, input_length, greedy=True)

        decode = K.ctc_label_dense_to_sparse(decode[0], K.cast(input_length, 'int32'))
        y_true_sparse = K.ctc_label_dense_to_sparse(y_true, K.cast(input_length, 'int32'))
        y_true_sparse = tf.sparse.retain(y_true_sparse, tf.not_equal(y_true_sparse.values, tf.math.reduce_max(y_true_sparse.values)))

        decode = tf.sparse.retain(decode, tf.not_equal(decode.values, -1))
        distance = tf.edit_distance(decode, y_true_sparse, normalize=True)

        self.cer_accumulator.assign_add(tf.reduce_sum(distance))
        self.counter.assign_add(K.cast(tf.shape(y_true)[0], 'float32'))

    def result(self):
        return tf.math.divide_no_nan(self.cer_accumulator, self.counter)

    def reset_state(self):
        self.cer_accumulator.assign(0.0)
        self.counter.assign(0.0)


def CTCLoss(y_true, y_pred):
    """
    Compute the training-time loss value
    """
    batch_len = tf.cast(tf.shape(y_true)[0], dtype="int64")
    input_length = tf.cast(tf.shape(y_pred)[1], dtype="int64")
    label_length = tf.cast(tf.shape(y_true)[1], dtype="int64")

    input_length = input_length * tf.ones(shape=(batch_len, 1), dtype="int64")
    label_length = label_length * tf.ones(shape=(batch_len, 1), dtype="int64")

    loss = K.ctc_batch_cost(y_true, y_pred, input_length, label_length)
    return loss

# %%
model = Sequential()

model.add(Conv2D(64, (5, 5), padding='same', activation=LeakyReLU(alpha=0.01), input_shape=(800, 64, 1)))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(128, (5, 5), padding='same', activation=LeakyReLU(alpha=0.01)))
model.add(MaxPooling2D((1, 2)))

model.add(Conv2D(128, (3, 3), padding='same', activation=LeakyReLU(alpha=0.01)))
model.add(MaxPooling2D((2, 2)))
model.add(BatchNormalization())

model.add(Conv2D(256, (3, 3), padding='same', activation=LeakyReLU(alpha=0.01)))

model.add(Conv2D(256, (3, 3), padding='same', activation=LeakyReLU(alpha=0.01)))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(512, (3, 3), padding='same', activation=LeakyReLU(alpha=0.01)))
model.add(MaxPooling2D((1, 2)))
model.add(BatchNormalization())

model.add(Conv2D(512, (3, 3), padding='same', activation=LeakyReLU(alpha=0.01)))
model.add(MaxPooling2D((1, 2)))

model.add(Reshape((100, 512)))

model.add(Bidirectional(LSTM(256, return_sequences=True)))
model.add(Bidirectional(LSTM(256, return_sequences=True)))

model.add(Dense(len(alphabet) + 1, activation='softmax')) # +1 for ctc blank

model.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 800, 64, 64)         │           1,664 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 400, 32, 64)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 400, 32, 128)        │         204,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 400, 16, 128)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 400, 16, 128)        │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 200, 8, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 200, 8, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 200, 8, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 200, 8, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 100, 4, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 100, 4, 512)         │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 100, 2, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 100, 2, 512)         │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (None, 100, 2, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_5 (MaxPooling2D)       │ (None, 100, 1, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ reshape (Reshape)                    │ (None, 100, 512)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional (Bidirectional)        │ (None, 100, 512)            │       1,574,912 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_1 (Bidirectional)      │ (None, 100, 512)            │       1,574,912 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 100, 57)             │          29,241 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 7,961,017 (30.37 MB)
#  Trainable params: 7,959,737 (30.36 MB)
#  Non-trainable params: 1,280 (5.00 KB)

# %%
model.compile(optimizer=Nadam(learning_rate=0.001, clipnorm=1.0), loss=CTCLoss, metrics=[CERMetric()])

# %% [markdown]
# # Train model

# %%
history = model.fit(train_X, train_y, validation_data=(val_X, val_y),
                    epochs=75, batch_size=64,
                    callbacks=[EarlyStopping(patience=10, restore_best_weights=True, monitor='val_CER_metric', mode='min'),
                              ReduceLROnPlateau(factor=0.5, min_lr=1e-5, patience=4, monitor='val_CER_metric', mode='min')],
                    verbose=1)
# Out:
# Epoch 1/75
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 42s 624ms/step - CER_metric: 0.5974 - loss: 81.3180 - val_CER_metric: 1.0000 - val_loss: 267.7709 - learning_rate: 0.0010
# Epoch 2/75
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 82s 627ms/step - CER_metric: 0.3088 - loss: 41.7238 - val_CER_metric: 1.0000 - val_loss: 268.1590 - learning_rate: 0.0010
# Epoch 3/75
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 42s 618ms/step - CER_metric: 0.1961 - loss: 25.4789 - val_CER_metric: 0.9993 - val_loss: 299.6614 - learning_rate: 0.0010
# Epoch 4/75
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 83s 630ms/step - CER_metric: 0.1741 - loss: 18.0616 - val_CER_metric: 0.9740 - val_loss: 264.2059 - learning_rate: 0.0010
# Epoch 5/75
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 81s 622ms/step - CER_metric: 0.0976 - loss: 13.1132 - val_CER_metric: 0.6691 - val_loss: 121.1865 - learning_rate: 0.0010
# Epoch 6/75
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 82s 618ms/step - CER_metric: 0.0837 - loss: 9.6098 - val_CER_metric: 0.4107 - val_loss: 59.5993 - learning_rate: 0.0010
# Epoch 7/75
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 82s 626ms/step - CER_metric: 0.0652 - loss: 7.0449 - val_CER_metric: 0.2017 - val_loss: 29.6932 - learning_rate: 0.0010
# Epoch 8/75
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 82s 621ms/step - CER_metric: 0.0414 - loss: 4.8319 - val_CER_metric: 0.1544 - val_loss: 22.5186 - learning_rate: 0.0010
# Epoch 9/75
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 83s 629ms/step - CER_metric: 0.0354 - loss: 3.8482 - val_CER_metric: 0.1356 - val_loss: 20.9553 - learning_rate: 0.0010
# Epoch 10/75
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 42s 624ms/step - CER_metric: 0.0268 - loss: 3.0620 - val_CER_metric: 0.1409 - val_loss: 22.6576 - learning_rate: 0.0010
# Epoch 11/75
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 42s 620ms/step - CER_metric: 0.0190 - loss: 2.3775 - val_CER_metric: 0.1543 - val_loss: 25.0853 - learning_rate: 0.0010
# Epoch 12/75
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 82s 621ms/step - CER_metric: 0.0171 - loss: 2.0854 - val_CER_metric: 0.1431 - val_loss: 24.7842 - learning_rate: 0.0010
# Epoch 13/75
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 42s 619ms/step - CER_metric: 0.0153 - loss: 1.7830 - val_CER_metric: 0.1282 - val_loss: 24.0469 - learning_rate: 0.0010
# Epoch 14/75
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 83s 628ms/step - CER_metric: 0.0134 - loss: 1.6228 - val_CER_metric: 0.1381 - val_loss: 25.3301 - learning_rate: 0.0010
# Epoch 15/75
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 81s 619ms/step - CER_metric: 0.0122 - loss: 1.4662 - val_CER_metric: 0.1356 - val_loss: 24.9899 - learning_rate: 0.0010
# Epoch 16/75
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 82s 620ms/step - CER_metric: 0.0115 - loss: 1.3345 - val_CER_metric: 0.1283 - val_loss: 25.0870 - learning_rate: 0.0010
# Epoch 17/75
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 82s 621ms/step - CER_metric: 0.0102 - loss: 1.2765 - val_CER_metric: 0.1346 - val_loss: 25.7742 - learning_rate: 0.0010
# Epoch 18/75
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 82s 618ms/step - CER_metric: 0.0055 - loss: 0.7341 - val_CER_metric: 0.1183 - val_loss: 24.8033 - learning_rate: 5.0000e-04
# Epoch 19/75
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 83s 629ms/step - CER_metric: 0.0022 - loss: 0.3008 - val_CER_metric: 0.1228 - val_loss: 26.0692 - learning_rate: 5.0000e-04
# Epoch 20/75
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 42s 620ms/step - CER_metric: 0.0016 - loss: 0.2256 - val_CER_metric: 0.1192 - val_loss: 26.0110 - learning_rate: 5.0000e-04
# Epoch 21/75
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 42s 619ms/step - CER_metric: 0.0019 - loss: 0.2305 - val_CER_metric: 0.1187 - val_loss: 25.7432 - learning_rate: 5.0000e-04
# Epoch 22/75
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 82s 620ms/step - CER_metric: 0.0013 - loss: 0.1977 - val_CER_metric: 0.1200 - val_loss: 26.1982 - learning_rate: 5.0000e-04
# Epoch 23/75
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 83s 628ms/step - CER_metric: 6.7780e-04 - loss: 0.1309 - val_CER_metric: 0.1129 - val_loss: 26.0145 - learning_rate: 2.5000e-04
# Epoch 24/75
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 42s 619ms/step - CER_metric: 2.4466e-04 - loss: 0.0450 - val_CER_metric: 0.1126 - val_loss: 26.4942 - learning_rate: 2.5000e-04
# Epoch 25/75
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 82s 618ms/step - CER_metric: 1.6197e-04 - loss: 0.0252 - val_CER_metric: 0.1104 - val_loss: 25.4714 - learning_rate: 2.5000e-04
# Epoch 26/75
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 87s 689ms/step - CER_metric: 7.2983e-06 - loss: 0.0135 - val_CER_metric: 0.1096 - val_loss: 25.6919 - learning_rate: 2.5000e-04
# Epoch 27/75
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 77s 621ms/step - CER_metric: 1.6278e-06 - loss: 0.0118 - val_CER_metric: 0.1092 - val_loss: 25.8267 - learning_rate: 2.5000e-04
# Epoch 28/75
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 42s 615ms/step - CER_metric: 1.9433e-05 - loss: 0.0104 - val_CER_metric: 0.1094 - val_loss: 25.8792 - learning_rate: 2.5000e-04
# Epoch 29/75
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 82s 622ms/step - CER_metric: 3.8742e-07 - loss: 0.0087 - val_CER_metric: 0.1090 - val_loss: 25.9604 - learning_rate: 2.5000e-04
# Epoch 30/75
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 82s 620ms/step - CER_metric: 2.5719e-05 - loss: 0.0094 - val_CER_metric: 0.1093 - val_loss: 26.0856 - learning_rate: 2.5000e-04
# Epoch 31/75
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 82s 617ms/step - CER_metric: 0.0000e+00 - loss: 0.0068 - val_CER_metric: 0.1092 - val_loss: 26.1522 - learning_rate: 2.5000e-04
# Epoch 32/75
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 82s 621ms/step - CER_metric: 0.0000e+00 - loss: 0.0071 - val_CER_metric: 0.1091 - val_loss: 26.2529 - learning_rate: 2.5000e-04
# Epoch 33/75
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 42s 621ms/step - CER_metric: 0.0000e+00 - loss: 0.0069 - val_CER_metric: 0.1093 - val_loss: 26.3605 - learning_rate: 2.5000e-04
# Epoch 34/75
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 42s 614ms/step - CER_metric: 1.3370e-06 - loss: 0.0059 - val_CER_metric: 0.1091 - val_loss: 26.3852 - learning_rate: 1.2500e-04
# Epoch 35/75
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 82s 621ms/step - CER_metric: 0.0000e+00 - loss: 0.0059 - val_CER_metric: 0.1093 - val_loss: 26.4106 - learning_rate: 1.2500e-04
# Epoch 36/75
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 42s 625ms/step - CER_metric: 0.0000e+00 - loss: 0.0054 - val_CER_metric: 0.1094 - val_loss: 26.4429 - learning_rate: 1.2500e-04
# Epoch 37/75
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 82s 622ms/step - CER_metric: 0.0000e+00 - loss: 0.0061 - val_CER_metric: 0.1093 - val_loss: 26.4920 - learning_rate: 1.2500e-04
# Epoch 38/75
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 42s 616ms/step - CER_metric: 0.0000e+00 - loss: 0.0049 - val_CER_metric: 0.1093 - val_loss: 26.5054 - learning_rate: 6.2500e-05
# Epoch 39/75
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 82s 624ms/step - CER_metric: 0.0000e+00 - loss: 0.0050 - val_CER_metric: 0.1090 - val_loss: 26.5417 - learning_rate: 6.2500e-05
# Epoch 40/75
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 82s 620ms/step - CER_metric: 0.0000e+00 - loss: 0.0051 - val_CER_metric: 0.1091 - val_loss: 26.5610 - learning_rate: 6.2500e-05
# Epoch 41/75
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 42s 617ms/step - CER_metric: 0.0000e+00 - loss: 0.0050 - val_CER_metric: 0.1093 - val_loss: 26.5755 - learning_rate: 6.2500e-05
# Epoch 42/75
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 82s 622ms/step - CER_metric: 0.0000e+00 - loss: 0.0048 - val_CER_metric: 0.1093 - val_loss: 26.5820 - learning_rate: 3.1250e-05
# Epoch 43/75
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 82s 623ms/step - CER_metric: 0.0000e+00 - loss: 0.0048 - val_CER_metric: 0.1092 - val_loss: 26.5949 - learning_rate: 3.1250e-05
# Epoch 44/75
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 82s 619ms/step - CER_metric: 0.0000e+00 - loss: 0.0046 - val_CER_metric: 0.1091 - val_loss: 26.6080 - learning_rate: 3.1250e-05
# Epoch 45/75
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 82s 624ms/step - CER_metric: 0.0000e+00 - loss: 0.0048 - val_CER_metric: 0.1091 - val_loss: 26.6220 - learning_rate: 3.1250e-05
# Epoch 46/75
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 42s 620ms/step - CER_metric: 0.0000e+00 - loss: 0.0047 - val_CER_metric: 0.1090 - val_loss: 26.6308 - learning_rate: 1.5625e-05
# Epoch 47/75
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 82s 618ms/step - CER_metric: 0.0000e+00 - loss: 0.0056 - val_CER_metric: 0.1090 - val_loss: 26.6371 - learning_rate: 1.5625e-05
# Epoch 48/75
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 42s 615ms/step - CER_metric: 0.0000e+00 - loss: 0.0053 - val_CER_metric: 0.1091 - val_loss: 26.6400 - learning_rate: 1.5625e-05
# Epoch 49/75
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 82s 623ms/step - CER_metric: 0.0000e+00 - loss: 0.0047 - val_CER_metric: 0.1092 - val_loss: 26.6403 - learning_rate: 1.5625e-05

# %%
fig, axes = plt.subplots(figsize=(12, 6), ncols=2, nrows=1)

axes[0].plot(history.history['loss'], label='loss')
axes[0].plot(history.history['val_loss'], label='val_loss')
axes[0].set_xlabel("Epoch")
axes[0].set_ylabel("Loss")
axes[0].legend()
axes[1].plot(history.history['CER_metric'], label='CER_metric')
axes[1].plot(history.history['val_CER_metric'], label='val_CER_metric')
axes[1].set_xlabel("Epoch")
axes[1].set_ylabel("Character Error Rate")
axes[1].legend()

plt.show()

# %%
model.save('./crnn.h5')

# %%
# model = load_model('path/to/model', custom_objects={'CTCLoss' : CTCLoss, 'CERMetric': CERMetric})

# %% [markdown]
# ## Model training results

# %%
# Test results: (loss, cer)

model.evaluate(test_X, test_y)
# Out:
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 9s 137ms/step - CER_metric: 0.0927 - loss: 25.4278
# [26.12023162841797, 0.09586028754711151]

# %%
# Decode label for single image

def num_to_label(num, alphabet):
    text = ""
    for ch in num:
        if ch == len(alphabet): # ctc blank
          break
        else:
          text += alphabet[ch]
    return text


# Decode labels for softmax matrix

def decode_text(nums):
  values = get_value(
      ctc_decode(nums, input_length=np.ones(nums.shape[0])*nums.shape[1],
                 greedy=True)[0][0])

  texts = []
  for i in range(nums.shape[0]):
    value = values[i]
    texts.append(num_to_label(value[value >= 0], alphabet))
  return texts

# %%
predicts = model.predict(test_X)
predicts = decode_text(predicts)
# Out:
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 5s 89ms/step

# %%
# Prediction results

fig, axes = plt.subplots(figsize=(30, 60), ncols=2, nrows=32)

test_X = test_X.astype('int')

# Title format: GT - Predict
for i in range(64):
  axes[i // 2, i % 2].imshow(cv2.rotate(
      (test_X[i]).astype(np.uint8),cv2.ROTATE_90_COUNTERCLOCKWISE),
      cmap='gray')
  axes[i // 2, i % 2].set_title(
      f'{num_to_label(test_y[i], alphabet)} - {predicts[i]}')
  axes[i // 2, i % 2].axis("off")
